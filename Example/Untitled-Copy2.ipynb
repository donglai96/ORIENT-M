# %%
import ORIENTM as orient


from datetime import datetime

start_time = datetime(2013,5,15)
end_time = datetime(2013,6,15)
input_time =  datetime(2013,6,1,3)

eflux_1 =  orient.eflux.model.ElectronFlux(start_time, end_time,instrument = 'mageis2',channel = 3)
final_frame, X_input_total = eflux_1.get_flux(dst_source='omni',
                 al_source='omni',
                 sw_source='omni',use_omni = True,use_traj = False,get_input_time = input_time,get_MLT_flux=True,
                                             selected_MLT_datetime = input_time)
# Out:
# 17-Apr-22 14:55:35: Downloading remote index: https://spdf.gsfc.nasa.gov/pub/data/omni/omni_cdaweb/hro2_5min/2013/
# version DM
# startmin -5760
# endmin 0
# lagstep 20
# input ['ae', 'dst', 'pressure', 'flow_speed']
# ORIENT-M initialized, Getting eflux from: mageis2 channel: 3
# Start loading the data... np_update is: False
# Get MLT flux mode is on
# 17-Apr-22 14:55:35: File is current: omni_data/hro2_5min/2013/omni_hro2_5min_20130501_v01.cdf
# 17-Apr-22 14:55:36: File is current: omni_data/hro2_5min/2013/omni_hro2_5min_20130601_v01.cdf
# 17-Apr-22 14:55:36: c:\programdata\anaconda3\lib\site-packages\astropy\_erfa\core.py:104: ErfaWarning: ERFA function "dtf2d" yielded 1 of "dubious year (Note 6)"
#   warnings.warn('ERFA function "' + func_name + '" yielded ' + wmsg, ErfaWarning)
# filling gap of ['AE_INDEX', 'AL_INDEX', 'SYM_H', 'flow_speed', 'Pressure', 'BZ_GSM']
# http://lasp.colorado.edu/space_weather/dsttemerin/archive/ae_2013_05.txt
# Downloaded  ae_CB_data/ae_2013_05.txt
# ...

# %%
eflux_1.make_plot(normmax = 10**5.5)
# Out:
# 17-Apr-22 14:55:53: c:\users\dongl\dropbox\donglai_new\research\orient-m\ORIENTM\eflux\model.py:573: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   ob = axs[5].pcolormesh(time_mesh, L_mesh, 10**self.plot_matrix.T, cmap='jet', norm=LogNorm(vmin=1, vmax=normmax)

# %%
eflux_1.makeMLTplot(normmax = 10**5.5)
# Out:
# 17-Apr-22 14:55:55: c:\users\dongl\dropbox\donglai_new\research\orient-m\ORIENTM\eflux\model.py:670: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   cs = axpolar.pcolor(self.theta_mesh, self.r_mesh, C,norm=LogNorm(vmin = 1,vmax=normmax),cmap = 'jet')
